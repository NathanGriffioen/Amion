# %%
import pandas as pd
import numpy as np
import re
import datetime as dt
import ics
rawdf = pd.read_csv('swap.txt', sep='\t', skip_blank_lines=True, names = ["shiftType", "Sun", "Mon", "Tue", "Wed", "Thu", "Fri", "Sat"])
rawdf.head(23)
# Out:
#               shiftType         Sun     Mon                               Tue  \
# 0                   NaN         NaN     NaN  Call Schedule, 2/1 to 5/31, 2024
# 1                   NaN         NaN     NaN                               NaN
# 2            Week 8a-4p         NaN     NaN                               NaN
# 3           Week 3p-11p         NaN     NaN                               NaN
# 4            Week night         NaN     NaN                               NaN
# 5       Friday 3pm-11pm         NaN     NaN                               NaN
# 6   Friday night 11p-9a         NaN     NaN                               NaN
# 7      Saturday 9am-4pm         NaN     NaN                               NaN
# 8       Saturday 3-11pm         NaN     NaN                               NaN
# 9     Saturday 11pm-9am         NaN     NaN                               NaN
# 10       Sunday 9am-4pm         NaN     NaN                               NaN
# 11        Sunday 3-11pm         NaN     NaN                               NaN
# 12        Sunday 11p-8a         NaN     NaN                               NaN
# 13      Holiday 9am-4pm         NaN     NaN                               NaN
# 14     Holiday 3pm-11pm         NaN     NaN                               NaN
# 15        Holiday night         NaN     NaN                               NaN
# 16          Hospitalist         NaN     NaN                               NaN
# 17              Surgery         NaN     NaN                               NaN
# 18      Anaesthesiology         NaN     NaN                               NaN
# 19                  NaN  4 February       5                                 6
# 20           Week 8a-4p         NaN    J.G.                              J.G.
# 21          Week 3p-11p         NaN    N.K.                              C.C.
# 22           Week night         NaN  Sue.H.                              D.S.
#
#      Wed         Thu      Fri   Sat
# 0    NaN         NaN      NaN   NaN
# 1    NaN  1 February        2     3
# 2    NaN        J.C.     A.W.   NaN
# 3    NaN      Sue.H.      NaN   NaN
# 4    NaN        D.S.      NaN   NaN
# 5    NaN         NaN     E.E.   NaN
# 6    NaN         NaN     R.B.   NaN
# 7    NaN         NaN      NaN  E.E.
# 8    NaN         NaN      NaN  A.K.
# 9    NaN         NaN      NaN  D.S.
# 10   NaN         NaN      NaN   NaN
# 11   NaN         NaN      NaN   NaN
# 12   NaN         NaN      NaN   NaN
# 13   NaN         NaN      NaN   NaN
# 14   NaN         NaN      NaN   NaN
# 15   NaN         NaN      NaN   NaN
# 16   NaN         NaN      NaN   NaN
# 17   NaN        B.O.  B. / R.  R.B.
# 18   NaN        K.L.     L.T.  L.T.
# 19     7           8        9    10
# 20  K.J.        C.C.     A.P.   NaN
# 21  E.E.        K.J.      NaN   NaN
# 22  D.S.        A.W.      NaN   NaN

# %%
df = pd.DataFrame(columns=["Start", "End", "Date", "ShiftNumber", "WeekDay", "Holiday", "ShiftType", "Doctor"])
df.head()
# Out:
# Empty DataFrame
# Columns: [Start, End, WeekDay, Holiday, ShiftType, Doctor]
# Index: []

# %%
shifttimes = {
    "Week 8a-4p": (dt.time(8, 0), dt.time(16, 0), 0),
    "Week 3p-11p": (dt.time(15, 0), dt.time(23, 0), 1),

    "Week night": (dt.time(23, 0), dt.time(9, 0), 2),

    "Friday 3pm-11pm": (dt.time(15, 0), dt.time(23, 0), 1),
    "Friday night 11p-9a": (dt.time(23, 0), dt.time(9, 0), 2),
    "Saturday 9am-4pm": (dt.time(9, 0), dt.time(16, 0), 0),
    "Saturday 3-11pm": (dt.time(15, 0), dt.time(23, 0), 1),
    "Saturday 11pm-9am": (dt.time(23, 0), dt.time(9, 0), 2),
    "Sunday 9am-4pm": (dt.time(9, 0), dt.time(16, 0), 0),
    "Sunday 3-11pm": (dt.time(15, 0), dt.time(23, 0), 1),
    "Sunday 11p-8a": (dt.time(23, 0), dt.time(8, 0), 2),
    "Holiday 9am-4pm": (dt.time(9, 0), dt.time(16, 0), 0),
    "Holiday 3pm-11pm": (dt.time(15, 0), dt.time(23, 0), 1),

    "Holiday night": (dt.time(23, 0), dt.time(9, 0), 2),

    "Hospitalist": (dt.time(0, 0), dt.time(0, 0)),
    "Surgery": (dt.time(0, 0), dt.time(0, 0)),
    "Anaesthesiology": (dt.time(0, 0), dt.time(0, 0)) 
}

# %%
activeMonth = None
activeYear = None
dayDict = None
for i, row in rawdf.iterrows():
    #IF HEADER ROW
    if pd.isnull(row["shiftType"]):
        #Range Header
        m = re.search(r'Call Schedule, (\d{1,2})/(\d{1,2}) to (\d{1,2})/(\d{1,2}), (\d{4})', str(row["Tue"]))
        if m:
            startMonth, startDay, endMonth, endDay, year = m.groups()
            startDate = dt.date(int(year), int(startMonth), int(startDay))
            endDate = dt.date(int(year), int(endMonth), int(endDay))
            activeMonth = startDate.month
            activeYear = startDate.year
        else:
            #Weekly Header
            dayDict = dict()
            for key in row[1:].keys():
                #print(key, row[key])
                m = re.search(r'^(\d{1,2}) (January|February|March|April|May|June|July|August|September|October|November|December)', str(row[key]))
                m2 = re.search(r'^(\d{1,2}) (?!January|February|March|April|May|June|July|August|September|October|November|December)(.*)$', str(row[key]))
                if m:
                    day, activeMonth = m.groups()
                    activeMonth = dt.datetime.strptime(activeMonth, "%B").month
                    day = int(day)
                    holiday = None
                elif m2:
                    day, holiday = m2.groups()   
                    day = int(day)  
                else:
                    day = row[key]
                    holiday = None
                if not pd.isnull(day):
                    day = int(day)
                    dayDict.update({key: (dt.date(activeYear, activeMonth, day), holiday)})
    
    else:
        assert dayDict is not None
        shiftType = row["shiftType"]
        StartTime, EndTime, ShiftNumber = shifttimes[shiftType]

        for key in row[1:].keys():
            if not pd.isnull(row[key]):
                date, holiday = dayDict[key]
                weekday = date.strftime("%A")
                doctor = row[key]

                if EndTime >= StartTime:
                    StartDateTime = dt.datetime.combine(date, StartTime)
                    EndDateTime = dt.datetime.combine(date, EndTime)
                
                else:
                    StartDateTime = dt.datetime.combine(date, StartTime)
                    EndDateTime = dt.datetime.combine(date + dt.timedelta(days=1), EndTime)

                df.loc[len(df)] = {
                                    "Start": StartDateTime,
                                    "End": EndDateTime,
                                    "Date": date,
                                    "ShiftNumber": ShiftNumber,
                                    "WeekDay": weekday,
                                    "Holiday": holiday,
                                    "ShiftType": shiftType,
                                    "Doctor": doctor
                                }

# %%
df.head()
# Out:
#                 Start                 End   WeekDay Holiday        ShiftType  \
# 0 2024-02-01 08:00:00 2024-02-01 16:00:00  Thursday    None       Week 8a-4p
# 1 2024-02-02 08:00:00 2024-02-02 16:00:00    Friday    None       Week 8a-4p
# 2 2024-02-01 15:00:00 2024-02-01 23:00:00  Thursday    None      Week 3p-11p
# 3 2024-02-01 23:00:00 2024-02-02 09:00:00  Thursday    None       Week night
# 4 2024-02-02 15:00:00 2024-02-02 23:00:00    Friday    None  Friday 3pm-11pm
#
#    Doctor
# 0    J.C.
# 1    A.W.
# 2  Sue.H.
# 3    D.S.
# 4    E.E.

# %%
C = ics.Calendar()
for i, row in df.iterrows():
    E = ics.Event()
    E.name = str(row["Doctor"]) + ' ' +  (row["ShiftType"]) + ' ' + str(row["WeekDay"]) + ' ' + str(row["Holiday"])
    E.begin = row["Start"]
    E.end = row["End"]
    C.events.add(E)

with open('my.ics', 'w') as my_file:
    my_file.writelines(C.serialize_iter())
